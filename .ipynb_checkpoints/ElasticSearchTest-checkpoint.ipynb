# %%
import requests

# %%
res = requests.get('http://localhost:9200')
print res.content
print res.status_code
# Out:
# {
#   "name" : "IHixwm0",
#   "cluster_name" : "elasticsearch",
#   "cluster_uuid" : "tXlu5mWFSbSkZgi18vP6lQ",
#   "version" : {
#     "number" : "5.1.1",
#     "build_hash" : "5395e21",
#     "build_date" : "2016-12-06T12:36:15.409Z",
#     "build_snapshot" : false,
#     "lucene_version" : "6.3.0"
#   },
#   "tagline" : "You Know, for Search"
# }
#
# 200

# %%
from elasticsearch import Elasticsearch
es = Elasticsearch([{'host':'localhost','port':9200}])

# %%
import json
r = requests.get('http://localhost:9200')
i = 1
while r.status_code == 200:
    r = requests.get('http://swapi.co/api/people/'+str(i))
    es.index(index='sw',doc_type='people',id=i, body=json.loads(r.content))
    i=i+1
    if i==5: print json.loads(r.content)
# Out:
# {u'starships': [u'http://swapi.co/api/starships/13/'], u'edited': u'2014-12-20T21:17:50.313000Z', u'name': u'Darth Vader', u'created': u'2014-12-10T15:18:20.704000Z', u'url': u'http://swapi.co/api/people/4/', u'gender': u'male', u'vehicles': [], u'skin_color': u'white', u'hair_color': u'none', u'height': u'202', u'eye_color': u'yellow', u'mass': u'136', u'films': [u'http://swapi.co/api/films/6/', u'http://swapi.co/api/films/3/', u'http://swapi.co/api/films/2/', u'http://swapi.co/api/films/1/'], u'species': [u'http://swapi.co/api/species/1/'], u'homeworld': u'http://swapi.co/api/planets/1/', u'birth_year': u'41.9BBY'}

# %%
es.get(index='sw', doc_type='people',id=5)
# Out:
# {u'_id': u'5',
#  u'_index': u'sw',
#  u'_source': {u'birth_year': u'19BBY',
#   u'created': u'2014-12-10T15:20:09.791000Z',
#   u'edited': u'2014-12-20T21:17:50.315000Z',
#   u'eye_color': u'brown',
#   u'films': [u'http://swapi.co/api/films/6/',
#    u'http://swapi.co/api/films/3/',
#    u'http://swapi.co/api/films/2/',
#    u'http://swapi.co/api/films/1/',
#    u'http://swapi.co/api/films/7/'],
#   u'gender': u'female',
#   u'hair_color': u'brown',
#   u'height': u'150',
#   u'homeworld': u'http://swapi.co/api/planets/2/',
#   u'mass': u'49',
#   u'name': u'Leia Organa',
#   u'skin_color': u'light',
#   u'species': [u'http://swapi.co/api/species/1/'],
#   u'starships': [],
#   u'url': u'http://swapi.co/api/people/5/',
#   u'vehicles': [u'http://swapi.co/api/vehicles/30/']},
#  u'_type': u'people',
#  u'_version': 2,
#  u'found': True}

# %%
r = requests.get('http://localhost:9200')
i = 1
while r.status_code == 200:
    r = requests.get('http://swapi.co/api/people/'+str(i))
    es.index(index='sw',doc_type='people',id=i, body=json.loads(r.content))
    i=i+1
    if i==17: i=i+1
print i
# Out:
# 90

# %%
es.search(index='sw', body = {"query": {"match": {'name': 'Darth Vader'}}})
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'4',
#     u'_index': u'sw',
#     u'_score': 3.5788128,
#     u'_source': {u'birth_year': u'41.9BBY',
#      u'created': u'2014-12-10T15:18:20.704000Z',
#      u'edited': u'2014-12-20T21:17:50.313000Z',
#      u'eye_color': u'yellow',
#      u'films': [u'http://swapi.co/api/films/6/',
#       u'http://swapi.co/api/films/3/',
#       u'http://swapi.co/api/films/2/',
#       u'http://swapi.co/api/films/1/'],
#      u'gender': u'male',
#      u'hair_color': u'none',
#      u'height': u'202',
#      u'homeworld': u'http://swapi.co/api/planets/1/',
#      u'mass': u'136',
#      u'name': u'Darth Vader',
#      u'skin_color': u'white',
#      u'species': [u'http://swapi.co/api/species/1/'],
#      u'starships': [u'http://swapi.co/api/starships/13/'],
#      u'url': u'http://swapi.co/api/people/4/',
#      u'vehicles': []},
#     u'_type': u'people'},
#    {u'_id': u'44',
#     u'_index': u'sw',
#     u'_score': 2.0980945,
#     u'_source': {u'birth_year': u'54BBY',
#      u'created': u'2014-12-19T18:00:41.929000Z',
#      u'edited': u'2014-12-20T21:17:50.403000Z',
#      u'eye_color': u'yellow',
#      u'films': [u'http://swapi.co/api/films/4/'],
#      u'gender': u'male',
#      u'hair_color': u'none',
#      u'height': u'175',
#      u'homeworld': u'http://swapi.co/api/planets/36/',
#      u'mass': u'80',
#      u'name': u'Darth Maul',
#      u'skin_color': u'red',
#      u'species': [u'http://swapi.co/api/species/22/'],
#      u'starships': [u'http://swapi.co/api/starships/41/'],
#      u'url': u'http://swapi.co/api/people/44/',
#      u'vehicles': [u'http://swapi.co/api/vehicles/42/']},
#     u'_type': u'people'}],
#   u'max_score': 3.5788128,
#   u'total': 2},
#  u'timed_out': False,
#  u'took': 54}

# %%
es.search(index='sw', body = {"query": {"prefix": {'name': 'lu'}}})
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'1',
#     u'_index': u'sw',
#     u'_score': 1.0,
#     u'_source': {u'birth_year': u'19BBY',
#      u'created': u'2014-12-09T13:50:51.644000Z',
#      u'edited': u'2014-12-20T21:17:56.891000Z',
#      u'eye_color': u'blue',
#      u'films': [u'http://swapi.co/api/films/6/',
#       u'http://swapi.co/api/films/3/',
#       u'http://swapi.co/api/films/2/',
#       u'http://swapi.co/api/films/1/',
#       u'http://swapi.co/api/films/7/'],
#      u'gender': u'male',
#      u'hair_color': u'blond',
#      u'height': u'172',
#      u'homeworld': u'http://swapi.co/api/planets/1/',
#      u'mass': u'77',
#      u'name': u'Luke Skywalker',
#      u'skin_color': u'fair',
#      u'species': [u'http://swapi.co/api/species/1/'],
#      u'starships': [u'http://swapi.co/api/starships/12/',
#       u'http://swapi.co/api/starships/22/'],
#      u'url': u'http://swapi.co/api/people/1/',
#      u'vehicles': [u'http://swapi.co/api/vehicles/14/',
#       u'http://swapi.co/api/vehicles/30/']},
#     u'_type': u'people'},
#    {u'_id': u'64',
#     u'_index': u'sw',
#     u'_score': 1.0,
#     u'_source': {u'birth_year': u'58BBY',
#      u'created': u'2014-12-20T16:45:53.668000Z',
#      u'edited': u'2014-12-20T21:17:50.455000Z',
#      u'eye_color': u'blue',
#      u'films': [u'http://swapi.co/api/films/5/',
#       u'http://swapi.co/api/films/6/'],
#      u'gender': u'female',
#      u'hair_color': u'black',
#      u'height': u'170',
#      u'homeworld': u'http://swapi.co/api/planets/51/',
#      u'mass': u'56.2',
#      u'name': u'Luminara Unduli',
#      u'skin_color': u'yellow',
#      u'species': [u'http://swapi.co/api/species/29/'],
#      u'starships': [],
#      u'url': u'http://swapi.co/api/people/64/',
#      u'vehicles': []},
#     u'_type': u'people'}],
#   u'max_score': 1.0,
#   u'total': 2},
#  u'timed_out': False,
#  u'took': 19}

# %%
g = open('/home/joey/Dropbox/LAB/category.txt','r')
line = g.readline()
cat_dict = {}
while line != '':
    vec = line.replace('\n','').split('\t')
    if not cat_dict.has_key(vec[0]):
        cat_dict[vec[0]]=vec[1]
    line = g.readline()
g.close()

# %%
f = open('/home/joey/Dropbox/Seg_sents.txt','r')
line = f.readline()
i = 1
while line != '':
    if 'cause' in line:
        vec = line.replace('\n','').split('$')
        content = {}
        tags = []
        tagged_tokens = []
        content['title'] = vec[0]
        content['sent'] = vec[2]
        sen_vec = vec[2].split(' ')
        content['tokens'] = sen_vec
        for item in sen_vec:
            if cat_dict.has_key(item):
                if cat_dict[item] == 'disease' or cat_dict[item] == 'symptom':
                    string = '<disease>'+item+'</disease>'
                    tagged_tokens.append(string)
                    tags.append('disease')
                else:
                    tags.append('NA')
                    tagged_tokens.append('NA')
            else:
                tags.append('NA')
                tagged_tokens.append('NA')
        content['tags'] = tags
        content['tagged_tokens'] = tagged_tokens
        content['id'] = i
        content['index'] = 'baidu'
        es.index(index='baidu',doc_type='cause',id=i, body=content)
        i = i + 1
    line = f.readline()
print i
f.close()

# %%
es.search(index='baidu', body = {"query": {"match": {'title': '外阴假上皮瘤样增生'}}})
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'1',
#     u'_index': u'baidu',
#     u'_score': 29.708136,
#     u'_source': {u'id': 1,
#      u'index': u'baidu',
#      u'sent': u'\u5177\u4f53 \u75c5\u56e0 \u4e0d\u8be6 \uff0c \u53ef\u80fd \u4e0e \u5916\u9634 \u6f6e\u6e7f \u6216 \u5206\u6ccc\u7269 \u957f\u671f \u523a\u6fc0 \u6709\u5173 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5916\u9634\u5047\u4e0a\u76ae\u7624\u6837\u589e\u751f',
#      u'tokens': [u'\u5177\u4f53',
#       u'\u75c5\u56e0',
#       u'\u4e0d\u8be6',
#       u'\uff0c',
#       u'\u53ef\u80fd',
#       u'\u4e0e',
#       u'\u5916\u9634',
#       u'\u6f6e\u6e7f',
#       u'\u6216',
#       u'\u5206\u6ccc\u7269',
#       u'\u957f\u671f',
#       u'\u523a\u6fc0',
#       u'\u6709\u5173',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'3',
#     u'_index': u'baidu',
#     u'_score': 29.68135,
#     u'_source': {u'id': 3,
#      u'index': u'baidu',
#      u'sent': u'\u5176\u4ed6 \u7684 \u5371\u9669 \u56e0\u7d20 \u6709 \u6027\u75c5 \u3001 \u809b\u95e8 - \u751f\u6b96\u9053 \u7624\u6837\u75c5\u53d8 \u3001 \u514d\u75ab\u6291\u5236 \u4ee5\u53ca \u5438\u70df \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u6027\u75c5</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u7624\u6837\u75c5\u53d8</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u5438\u70df</disease>',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA'],
#      u'title': u'\u5916\u9634\u5047\u4e0a\u76ae\u7624\u6837\u589e\u751f',
#      u'tokens': [u'\u5176\u4ed6',
#       u'\u7684',
#       u'\u5371\u9669',
#       u'\u56e0\u7d20',
#       u'\u6709',
#       u'\u6027\u75c5',
#       u'\u3001',
#       u'\u809b\u95e8',
#       u'-',
#       u'\u751f\u6b96\u9053',
#       u'\u7624\u6837\u75c5\u53d8',
#       u'\u3001',
#       u'\u514d\u75ab\u6291\u5236',
#       u'\u4ee5\u53ca',
#       u'\u5438\u70df',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'5',
#     u'_index': u'baidu',
#     u'_score': 28.849924,
#     u'_source': {u'id': 5,
#      u'index': u'baidu',
#      u'sent': u'\u9489\u811a \u95f4 \u53ef\u6709 \u6dcb\u5df4\u7ec6\u80de \u6216 \u5c11\u91cf \u6d46\u7ec6\u80de\u6d78\u6da6 \uff0c \u4f46 \u4e0a\u76ae\u7ec6\u80de \u6392\u5217 \u6574\u9f50 \uff0c \u7ec6\u80de \u5927\u5c0f \u3001 \u6781\u6027 \u3001 \u5f62\u6001 \u3001 \u67d3\u8272 \u6b63\u5e38 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u6d46\u7ec6\u80de\u6d78\u6da6</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5916\u9634\u5047\u4e0a\u76ae\u7624\u6837\u589e\u751f',
#      u'tokens': [u'\u9489\u811a',
#       u'\u95f4',
#       u'\u53ef\u6709',
#       u'\u6dcb\u5df4\u7ec6\u80de',
#       u'\u6216',
#       u'\u5c11\u91cf',
#       u'\u6d46\u7ec6\u80de\u6d78\u6da6',
#       u'\uff0c',
#       u'\u4f46',
#       u'\u4e0a\u76ae\u7ec6\u80de',
#       u'\u6392\u5217',
#       u'\u6574\u9f50',
#       u'\uff0c',
#       u'\u7ec6\u80de',
#       u'\u5927\u5c0f',
#       u'\u3001',
#       u'\u6781\u6027',
#       u'\u3001',
#       u'\u5f62\u6001',
#       u'\u3001',
#       u'\u67d3\u8272',
#       u'\u6b63\u5e38',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'2',
#     u'_index': u'baidu',
#     u'_score': 28.155165,
#     u'_source': {u'id': 2,
#      u'index': u'baidu',
#      u'sent': u'\u73b0\u4ee3 \u5206\u5b50 \u5b66 \u6280\u672f \u68c0\u6d4b \u53d1\u73b0 80 % VIN \u4f34\u6709 \u4eba\u7c7b\u4e73\u5934\u7624\u75c5\u6bd2 \uff08 Human   Papillomavirus \uff0c \u7b80\u79f0 HPV \uff09 \uff08 16 \u578b \uff09 \u611f\u67d3 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u4eba\u7c7b\u4e73\u5934\u7624\u75c5\u6bd2</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u611f\u67d3</disease>',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA'],
#      u'title': u'\u5916\u9634\u5047\u4e0a\u76ae\u7624\u6837\u589e\u751f',
#      u'tokens': [u'\u73b0\u4ee3',
#       u'\u5206\u5b50',
#       u'\u5b66',
#       u'\u6280\u672f',
#       u'\u68c0\u6d4b',
#       u'\u53d1\u73b0',
#       u'80',
#       u'%',
#       u'VIN',
#       u'\u4f34\u6709',
#       u'\u4eba\u7c7b\u4e73\u5934\u7624\u75c5\u6bd2',
#       u'\uff08',
#       u'Human',
#       u'',
#       u'',
#       u'Papillomavirus',
#       u'\uff0c',
#       u'\u7b80\u79f0',
#       u'HPV',
#       u'\uff09',
#       u'\uff08',
#       u'16',
#       u'\u578b',
#       u'\uff09',
#       u'\u611f\u67d3',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'4',
#     u'_index': u'baidu',
#     u'_score': 28.155165,
#     u'_source': {u'id': 4,
#      u'index': u'baidu',
#      u'sent': u'\u5916\u9634 \u8868\u76ae \u7684 \u68d8 \u7ec6\u80de\u5c42 \u589e\u751f \uff0c \u4e0a\u76ae \u811a \u5411\u4e0b \u5ef6\u4f38 \uff0c \u4f46 \u8d8a \u5411\u4e0b \u4f38\u5c55 \uff0c \u5219 \u7ec6\u80de\u51cf\u5c11 \u800c \u9489\u811a \u53d8\u7ec6 \uff0c \u672b\u7aef \u949d \u5706 \uff0c \u9489\u811a \u7684 \u5ef6\u4f38 \u65b9\u5411 \u5e73\u884c \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u589e\u751f</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u7ec6\u80de\u51cf\u5c11</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5916\u9634\u5047\u4e0a\u76ae\u7624\u6837\u589e\u751f',
#      u'tokens': [u'\u5916\u9634',
#       u'\u8868\u76ae',
#       u'\u7684',
#       u'\u68d8',
#       u'\u7ec6\u80de\u5c42',
#       u'\u589e\u751f',
#       u'\uff0c',
#       u'\u4e0a\u76ae',
#       u'\u811a',
#       u'\u5411\u4e0b',
#       u'\u5ef6\u4f38',
#       u'\uff0c',
#       u'\u4f46',
#       u'\u8d8a',
#       u'\u5411\u4e0b',
#       u'\u4f38\u5c55',
#       u'\uff0c',
#       u'\u5219',
#       u'\u7ec6\u80de\u51cf\u5c11',
#       u'\u800c',
#       u'\u9489\u811a',
#       u'\u53d8\u7ec6',
#       u'\uff0c',
#       u'\u672b\u7aef',
#       u'\u949d',
#       u'\u5706',
#       u'\uff0c',
#       u'\u9489\u811a',
#       u'\u7684',
#       u'\u5ef6\u4f38',
#       u'\u65b9\u5411',
#       u'\u5e73\u884c',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'2937',
#     u'_index': u'baidu',
#     u'_score': 12.08974,
#     u'_source': {u'id': 2937,
#      u'index': u'baidu',
#      u'sent': u'\u5448 \u7ed3\u8282 \u72b6 \u6216 \u5206 \u53f6\u72b6 \uff0c \u8868\u9762 \u5e38\u6709 \u4e00\u5c42 \u5047 \u5305\u819c \uff0c \u5207\u9762 \u5448\u8102 \u9ec4\u8272 \uff0c \u9ecf\u6db2 \u6837 \u6216 \u9c7c\u8089 \u6837 \uff0c \u5e38\u6709 \u51fa\u8840 \u3001 \u574f\u6b7b \u3002',
#      u'tagged_tokens': [u'NA',
#       u'<disease>\u7ed3\u8282</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u51fa\u8840</disease>',
#       u'NA',
#       u'<disease>\u574f\u6b7b</disease>',
#       u'NA'],
#      u'tags': [u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'disease',
#       u'NA'],
#      u'title': u'\u5916\u9634\u8102\u80aa\u8089\u7624',
#      u'tokens': [u'\u5448',
#       u'\u7ed3\u8282',
#       u'\u72b6',
#       u'\u6216',
#       u'\u5206',
#       u'\u53f6\u72b6',
#       u'\uff0c',
#       u'\u8868\u9762',
#       u'\u5e38\u6709',
#       u'\u4e00\u5c42',
#       u'\u5047',
#       u'\u5305\u819c',
#       u'\uff0c',
#       u'\u5207\u9762',
#       u'\u5448\u8102',
#       u'\u9ec4\u8272',
#       u'\uff0c',
#       u'\u9ecf\u6db2',
#       u'\u6837',
#       u'\u6216',
#       u'\u9c7c\u8089',
#       u'\u6837',
#       u'\uff0c',
#       u'\u5e38\u6709',
#       u'\u51fa\u8840',
#       u'\u3001',
#       u'\u574f\u6b7b',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'2939',
#     u'_index': u'baidu',
#     u'_score': 12.08974,
#     u'_source': {u'id': 2939,
#      u'index': u'baidu',
#      u'sent': u'\u8102\u6ef4 \u7a7a\u6ce1 \u8fb9\u754c \u6e05\u695a \uff0c \u5706\u800c \u5149\u6ed1 \uff0c \u5b8c\u5168 \u900f\u660e \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5916\u9634\u8102\u80aa\u8089\u7624',
#      u'tokens': [u'\u8102\u6ef4',
#       u'\u7a7a\u6ce1',
#       u'\u8fb9\u754c',
#       u'\u6e05\u695a',
#       u'\uff0c',
#       u'\u5706\u800c',
#       u'\u5149\u6ed1',
#       u'\uff0c',
#       u'\u5b8c\u5168',
#       u'\u900f\u660e',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'2945',
#     u'_index': u'baidu',
#     u'_score': 12.08974,
#     u'_source': {u'id': 2945,
#      u'index': u'baidu',
#      u'sent': u'\u514d\u75ab\u7ec4\u5316\u67d3\u8272 S - 100 \u4e0d\u89c4\u5219 \u9633\u6027 \u3002',
#      u'tagged_tokens': [u'NA', u'NA', u'NA', u'NA', u'NA', u'NA', u'NA'],
#      u'tags': [u'NA', u'NA', u'NA', u'NA', u'NA', u'NA', u'NA'],
#      u'title': u'\u5916\u9634\u8102\u80aa\u8089\u7624',
#      u'tokens': [u'\u514d\u75ab\u7ec4\u5316\u67d3\u8272',
#       u'S',
#       u'-',
#       u'100',
#       u'\u4e0d\u89c4\u5219',
#       u'\u9633\u6027',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'5448',
#     u'_index': u'baidu',
#     u'_score': 12.08974,
#     u'_source': {u'id': 5448,
#      u'index': u'baidu',
#      u'sent': u'\u53ef\u89c1 \u660e\u663e \u7684 \u68d8\u5c42 \u7ec6\u80de\u589e\u751f \u80a5\u539a \uff0c \u4e0a\u76ae \u5411 \u8868\u9762 \u7a81\u51fa \uff0c \u5f62\u6210 \u591a\u6570 \u7684 \u4e73\u5934\u72b6 \u5f62\u6001 \uff0c \u4e0a\u76ae \u811a \u53d8\u7c97 \u5411 \u771f\u76ae \u7ea4\u7ef4\u7ed3\u7f14\u7ec4\u7ec7 \u5185 \u4f38\u5c55 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u7ec6\u80de\u589e\u751f</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5916\u9634\u4e73\u5934\u72b6\u7624',
#      u'tokens': [u'\u53ef\u89c1',
#       u'\u660e\u663e',
#       u'\u7684',
#       u'\u68d8\u5c42',
#       u'\u7ec6\u80de\u589e\u751f',
#       u'\u80a5\u539a',
#       u'\uff0c',
#       u'\u4e0a\u76ae',
#       u'\u5411',
#       u'\u8868\u9762',
#       u'\u7a81\u51fa',
#       u'\uff0c',
#       u'\u5f62\u6210',
#       u'\u591a\u6570',
#       u'\u7684',
#       u'\u4e73\u5934\u72b6',
#       u'\u5f62\u6001',
#       u'\uff0c',
#       u'\u4e0a\u76ae',
#       u'\u811a',
#       u'\u53d8\u7c97',
#       u'\u5411',
#       u'\u771f\u76ae',
#       u'\u7ea4\u7ef4\u7ed3\u7f14\u7ec4\u7ec7',
#       u'\u5185',
#       u'\u4f38\u5c55',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'5449',
#     u'_index': u'baidu',
#     u'_score': 12.08974,
#     u'_source': {u'id': 5449,
#      u'index': u'baidu',
#      u'sent': u'\u80bf\u7624 \u6076\u53d8 \u7387\u4f4e \uff0c \u4e3a   f - 2 - 5   % \uff5e 3 % \u3002',
#      u'tagged_tokens': [u'<disease>\u80bf\u7624</disease>',
#       u'<disease>\u6076\u53d8</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'disease',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5916\u9634\u4e73\u5934\u72b6\u7624',
#      u'tokens': [u'\u80bf\u7624',
#       u'\u6076\u53d8',
#       u'\u7387\u4f4e',
#       u'\uff0c',
#       u'\u4e3a',
#       u'',
#       u'',
#       u'f',
#       u'-',
#       u'2',
#       u'-',
#       u'5',
#       u'',
#       u'',
#       u'%',
#       u'\uff5e',
#       u'3',
#       u'%',
#       u'\u3002']},
#     u'_type': u'cause'}],
#   u'max_score': 29.708136,
#   u'total': 1806},
#  u'timed_out': False,
#  u'took': 167}

# %%
es.search(index='baidu', body = {"query": {"bool": {"must": [{"match": {'title': '小儿支气管扩张'}},{"match": {'tokens': '体液免疫缺陷'}}]}}})
# Out:
# {u'_shards': {u'failed': 0, u'successful': 5, u'total': 5},
#  u'hits': {u'hits': [{u'_id': u'11',
#     u'_index': u'baidu',
#     u'_score': 51.66565,
#     u'_source': {u'id': 11,
#      u'index': u'baidu',
#      u'sent': u'\u4e3b\u8981 \u5305\u62ec \u4f53\u6db2\u514d\u75ab\u7f3a\u9677 \u3001 \u5c40\u90e8 \u514d\u75ab \u9632\u5fa1 \u7f3a\u9677 \u548c \u514d\u75ab \u7d0a\u4e71 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5c0f\u513f\u652f\u6c14\u7ba1\u6269\u5f20',
#      u'tokens': [u'\u4e3b\u8981',
#       u'\u5305\u62ec',
#       u'\u4f53\u6db2\u514d\u75ab\u7f3a\u9677',
#       u'\u3001',
#       u'\u5c40\u90e8',
#       u'\u514d\u75ab',
#       u'\u9632\u5fa1',
#       u'\u7f3a\u9677',
#       u'\u548c',
#       u'\u514d\u75ab',
#       u'\u7d0a\u4e71',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'12',
#     u'_index': u'baidu',
#     u'_score': 45.183037,
#     u'_source': {u'id': 12,
#      u'index': u'baidu',
#      u'sent': u'\u5176\u4e2d \uff0c \u6700 \u591a\u89c1\u4e8e \u4f53\u6db2\u514d\u75ab\u7f3a\u9677 \u7684 \u75c5\u4eba \uff0c \u5982 X \u8fde\u9501 \u7684 \u4f4e\u4e19\u79cd\u7403\u86cb\u767d\u8840\u75c7 \u3001 \u666e\u901a \u53d8\u5f02\u578b\u514d\u75ab\u7f3a\u9677\u75c5 \uff0c IgG \u4e9a\u7c7b \u7f3a\u9677 \u4e5f \u4e3a \u652f\u6c14\u7ba1\u6269\u5f20 \u7684 \u75c5\u56e0 \u4e4b\u4e00 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u4f4e\u4e19\u79cd\u7403\u86cb\u767d\u8840\u75c7</disease>',
#       u'NA',
#       u'NA',
#       u'<disease>\u53d8\u5f02\u578b\u514d\u75ab\u7f3a\u9677\u75c5</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u652f\u6c14\u7ba1\u6269\u5f20</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5c0f\u513f\u652f\u6c14\u7ba1\u6269\u5f20',
#      u'tokens': [u'\u5176\u4e2d',
#       u'\uff0c',
#       u'\u6700',
#       u'\u591a\u89c1\u4e8e',
#       u'\u4f53\u6db2\u514d\u75ab\u7f3a\u9677',
#       u'\u7684',
#       u'\u75c5\u4eba',
#       u'\uff0c',
#       u'\u5982',
#       u'X',
#       u'\u8fde\u9501',
#       u'\u7684',
#       u'\u4f4e\u4e19\u79cd\u7403\u86cb\u767d\u8840\u75c7',
#       u'\u3001',
#       u'\u666e\u901a',
#       u'\u53d8\u5f02\u578b\u514d\u75ab\u7f3a\u9677\u75c5',
#       u'\uff0c',
#       u'IgG',
#       u'\u4e9a\u7c7b',
#       u'\u7f3a\u9677',
#       u'\u4e5f',
#       u'\u4e3a',
#       u'\u652f\u6c14\u7ba1\u6269\u5f20',
#       u'\u7684',
#       u'\u75c5\u56e0',
#       u'\u4e4b\u4e00',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'13',
#     u'_index': u'baidu',
#     u'_score': 37.48796,
#     u'_source': {u'id': 13,
#      u'index': u'baidu',
#      u'sent': u'\u5c40\u90e8 \u514d\u75ab \u9632\u5fa1 \u7f3a\u9677 \uff0c \u539f\u53d1 \u7ea4\u6bdb\u8fd0\u52a8\u969c\u788d \u7684 \u75c5\u4eba \uff0c \u7531\u4e8e \u7ea4\u6bdb\u8fd0\u52a8 \u4e0d\u826f \uff0c \u4ece\u800c \u5bfc\u81f4 \u9ecf\u6db2 \u7ea4\u6bdb \u6e05\u9664 \u529f\u80fd \u51cf\u4f4e \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u7ea4\u6bdb\u8fd0\u52a8\u969c\u788d</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5c0f\u513f\u652f\u6c14\u7ba1\u6269\u5f20',
#      u'tokens': [u'\u5c40\u90e8',
#       u'\u514d\u75ab',
#       u'\u9632\u5fa1',
#       u'\u7f3a\u9677',
#       u'\uff0c',
#       u'\u539f\u53d1',
#       u'\u7ea4\u6bdb\u8fd0\u52a8\u969c\u788d',
#       u'\u7684',
#       u'\u75c5\u4eba',
#       u'\uff0c',
#       u'\u7531\u4e8e',
#       u'\u7ea4\u6bdb\u8fd0\u52a8',
#       u'\u4e0d\u826f',
#       u'\uff0c',
#       u'\u4ece\u800c',
#       u'\u5bfc\u81f4',
#       u'\u9ecf\u6db2',
#       u'\u7ea4\u6bdb',
#       u'\u6e05\u9664',
#       u'\u529f\u80fd',
#       u'\u51cf\u4f4e',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'9909',
#     u'_index': u'baidu',
#     u'_score': 34.7228,
#     u'_source': {u'id': 9909,
#      u'index': u'baidu',
#      u'sent': u'\u673a\u4f53 \u514d\u75ab \u529f\u80fd\u5931\u8c03 \uff0c \u514d\u75ab\u7f3a\u9677 \uff0c \u5982 \u4f4e\u4e19\u79cd\u7403\u86cb\u767d\u8840\u75c7 \u8bf1\u53d1 \u53cd\u590d\u547c\u5438\u9053\u611f\u67d3 \uff0c \u53ef \u5f15\u8d77 \u652f\u6c14\u7ba1\u6269\u5f20 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'<disease>\u529f\u80fd\u5931\u8c03</disease>',
#       u'NA',
#       u'<disease>\u514d\u75ab\u7f3a\u9677</disease>',
#       u'NA',
#       u'NA',
#       u'<disease>\u4f4e\u4e19\u79cd\u7403\u86cb\u767d\u8840\u75c7</disease>',
#       u'NA',
#       u'<disease>\u53cd\u590d\u547c\u5438\u9053\u611f\u67d3</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u652f\u6c14\u7ba1\u6269\u5f20</disease>',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA'],
#      u'title': u'\u8001\u5e74\u4eba\u652f\u6c14\u7ba1\u6269\u5f20',
#      u'tokens': [u'\u673a\u4f53',
#       u'\u514d\u75ab',
#       u'\u529f\u80fd\u5931\u8c03',
#       u'\uff0c',
#       u'\u514d\u75ab\u7f3a\u9677',
#       u'\uff0c',
#       u'\u5982',
#       u'\u4f4e\u4e19\u79cd\u7403\u86cb\u767d\u8840\u75c7',
#       u'\u8bf1\u53d1',
#       u'\u53cd\u590d\u547c\u5438\u9053\u611f\u67d3',
#       u'\uff0c',
#       u'\u53ef',
#       u'\u5f15\u8d77',
#       u'\u652f\u6c14\u7ba1\u6269\u5f20',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'10',
#     u'_index': u'baidu',
#     u'_score': 34.101826,
#     u'_source': {u'id': 10,
#      u'index': u'baidu',
#      u'sent': u'\u652f\u6c14\u7ba1\u6269\u5f20 \u548c \u673a\u4f53 \u4e00\u4e9b \u7279\u5f02\u6027 \u7684 \u9632\u5fa1 \u529f\u80fd\u7f3a\u9677 \u6709\u5173 \u3002',
#      u'tagged_tokens': [u'<disease>\u652f\u6c14\u7ba1\u6269\u5f20</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u529f\u80fd\u7f3a\u9677</disease>',
#       u'NA',
#       u'NA'],
#      u'tags': [u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5c0f\u513f\u652f\u6c14\u7ba1\u6269\u5f20',
#      u'tokens': [u'\u652f\u6c14\u7ba1\u6269\u5f20',
#       u'\u548c',
#       u'\u673a\u4f53',
#       u'\u4e00\u4e9b',
#       u'\u7279\u5f02\u6027',
#       u'\u7684',
#       u'\u9632\u5fa1',
#       u'\u529f\u80fd\u7f3a\u9677',
#       u'\u6709\u5173',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'6374',
#     u'_index': u'baidu',
#     u'_score': 27.105198,
#     u'_source': {u'id': 6374,
#      u'index': u'baidu',
#      u'sent': u'\u540c\u65f6 \u8fd8 \u5b58\u5728 \u7740 \u4f53\u6db2 \u514d\u75ab\u5f02\u5e38 \u548c \u7ec6\u80de\u514d\u75ab\u7f3a\u9677 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u514d\u75ab\u5f02\u5e38</disease>',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5c0f\u513f\u7d2b\u6591\u6e7f\u75b9\u7efc\u5408\u5f81',
#      u'tokens': [u'\u540c\u65f6',
#       u'\u8fd8',
#       u'\u5b58\u5728',
#       u'\u7740',
#       u'\u4f53\u6db2',
#       u'\u514d\u75ab\u5f02\u5e38',
#       u'\u548c',
#       u'\u7ec6\u80de\u514d\u75ab\u7f3a\u9677',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'7403',
#     u'_index': u'baidu',
#     u'_score': 25.066101,
#     u'_source': {u'id': 7403,
#      u'index': u'baidu',
#      u'sent': u'\u514d\u75ab\u7f3a\u9677   \u5305\u62ec \u4f53\u6db2 \u53ca \u7ec6\u80de\u514d\u75ab\u7f3a\u9677 \uff0c \u8865\u4f53 \u7f3a\u4e4f \u53ca \u767d\u7ec6\u80de \u541e\u566c\u529f\u80fd\u7f3a\u9677 \uff0c \u7686 \u53ef\u81f4 \u80ba\u708e \u53cd\u590d\u53d1\u4f5c \uff0c \u6700\u540e \u53d8\u6210 \u6162\u6027 \u3002',
#      u'tagged_tokens': [u'<disease>\u514d\u75ab\u7f3a\u9677</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u541e\u566c\u529f\u80fd\u7f3a\u9677</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u80ba\u708e</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u5c0f\u513f\u6162\u6027\u80ba\u708e',
#      u'tokens': [u'\u514d\u75ab\u7f3a\u9677',
#       u'',
#       u'',
#       u'\u5305\u62ec',
#       u'\u4f53\u6db2',
#       u'\u53ca',
#       u'\u7ec6\u80de\u514d\u75ab\u7f3a\u9677',
#       u'\uff0c',
#       u'\u8865\u4f53',
#       u'\u7f3a\u4e4f',
#       u'\u53ca',
#       u'\u767d\u7ec6\u80de',
#       u'\u541e\u566c\u529f\u80fd\u7f3a\u9677',
#       u'\uff0c',
#       u'\u7686',
#       u'\u53ef\u81f4',
#       u'\u80ba\u708e',
#       u'\u53cd\u590d\u53d1\u4f5c',
#       u'\uff0c',
#       u'\u6700\u540e',
#       u'\u53d8\u6210',
#       u'\u6162\u6027',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'9906',
#     u'_index': u'baidu',
#     u'_score': 23.523544,
#     u'_source': {u'id': 9906,
#      u'index': u'baidu',
#      u'sent': u'\u80ba\u56ca\u6027\u7ea4\u7ef4\u5316 \u662f \u7531\u4e8e \u672b\u68a2 \u80ba \u7ec4\u7ec7 \u53d1\u80b2\u4e0d\u826f \uff0c \u5c0f \u7ec6\u652f\u6c14\u7ba1 \u5448 \u67f1\u72b6 \uff0c \u56ca\u72b6\u6269\u5f20 \uff0c \u652f\u6c14\u7ba1 \u9ecf\u6db2 \u817a \u5206\u6ccc \u5927\u91cf \u9ecf\u6db2 \uff0c \u5f15\u8d77 \u963b\u585e \u80ba\u4e0d\u5f20 \u548c \u7ee7\u53d1\u611f\u67d3 \uff0c \u5bfc\u81f4 \u652f\u6c14\u7ba1\u6269\u5f20 \u3002',
#      u'tagged_tokens': [u'<disease>\u80ba\u56ca\u6027\u7ea4\u7ef4\u5316</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u53d1\u80b2\u4e0d\u826f</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u56ca\u72b6\u6269\u5f20</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u80ba\u4e0d\u5f20</disease>',
#       u'NA',
#       u'<disease>\u7ee7\u53d1\u611f\u67d3</disease>',
#       u'NA',
#       u'NA',
#       u'<disease>\u652f\u6c14\u7ba1\u6269\u5f20</disease>',
#       u'NA'],
#      u'tags': [u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA'],
#      u'title': u'\u8001\u5e74\u4eba\u652f\u6c14\u7ba1\u6269\u5f20',
#      u'tokens': [u'\u80ba\u56ca\u6027\u7ea4\u7ef4\u5316',
#       u'\u662f',
#       u'\u7531\u4e8e',
#       u'\u672b\u68a2',
#       u'\u80ba',
#       u'\u7ec4\u7ec7',
#       u'\u53d1\u80b2\u4e0d\u826f',
#       u'\uff0c',
#       u'\u5c0f',
#       u'\u7ec6\u652f\u6c14\u7ba1',
#       u'\u5448',
#       u'\u67f1\u72b6',
#       u'\uff0c',
#       u'\u56ca\u72b6\u6269\u5f20',
#       u'\uff0c',
#       u'\u652f\u6c14\u7ba1',
#       u'\u9ecf\u6db2',
#       u'\u817a',
#       u'\u5206\u6ccc',
#       u'\u5927\u91cf',
#       u'\u9ecf\u6db2',
#       u'\uff0c',
#       u'\u5f15\u8d77',
#       u'\u963b\u585e',
#       u'\u80ba\u4e0d\u5f20',
#       u'\u548c',
#       u'\u7ee7\u53d1\u611f\u67d3',
#       u'\uff0c',
#       u'\u5bfc\u81f4',
#       u'\u652f\u6c14\u7ba1\u6269\u5f20',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'9921',
#     u'_index': u'baidu',
#     u'_score': 22.230537,
#     u'_source': {u'id': 9921,
#      u'index': u'baidu',
#      u'sent': u'\u80ba\u6d3b\u91cf \uff08 VC \uff09 \u548c \u7528\u529b\u80ba\u6d3b\u91cf \uff08 FVC \uff09 \u5747 \u660e\u663e \u51cf\u5c11 \uff0c \u7531\u4e8e \u8001\u5e74\u4eba \u80f8\u5ed3 \u53ca \u80ba \u7684 \u5f39\u6027 \u51cf\u5f31 \uff0c \u547c\u5438 \u808c\u529b\u51cf\u9000 \u7b49 \u56e0\u7d20 \u4f7f \u5916\u5468 \u6c14\u9053 \u65e9\u671f \u9677\u95ed \u3002',
#      u'tagged_tokens': [u'<disease>\u80ba\u6d3b\u91cf</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u808c\u529b\u51cf\u9000</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u8001\u5e74\u4eba\u652f\u6c14\u7ba1\u6269\u5f20',
#      u'tokens': [u'\u80ba\u6d3b\u91cf',
#       u'\uff08',
#       u'VC',
#       u'\uff09',
#       u'\u548c',
#       u'\u7528\u529b\u80ba\u6d3b\u91cf',
#       u'\uff08',
#       u'FVC',
#       u'\uff09',
#       u'\u5747',
#       u'\u660e\u663e',
#       u'\u51cf\u5c11',
#       u'\uff0c',
#       u'\u7531\u4e8e',
#       u'\u8001\u5e74\u4eba',
#       u'\u80f8\u5ed3',
#       u'\u53ca',
#       u'\u80ba',
#       u'\u7684',
#       u'\u5f39\u6027',
#       u'\u51cf\u5f31',
#       u'\uff0c',
#       u'\u547c\u5438',
#       u'\u808c\u529b\u51cf\u9000',
#       u'\u7b49',
#       u'\u56e0\u7d20',
#       u'\u4f7f',
#       u'\u5916\u5468',
#       u'\u6c14\u9053',
#       u'\u65e9\u671f',
#       u'\u9677\u95ed',
#       u'\u3002']},
#     u'_type': u'cause'},
#    {u'_id': u'9914',
#     u'_index': u'baidu',
#     u'_score': 21.691328,
#     u'_source': {u'id': 9914,
#      u'index': u'baidu',
#      u'sent': u'\u5e7c\u5e74 \u652f\u6c14\u7ba1 \u53d1\u80b2\u9636\u6bb5 \u4ea7\u751f \u7684 \u652f\u6c14\u7ba1\u6269\u5f20 \u591a\u4e3a \u56ca \u72b6 \uff0c \u6210\u5e74 \u540e \u708e\u75c7 \u7ee7\u53d1 \u7684 \u6269\u5f20 \u5219 \u591a \u4e3a \u67f1\u72b6 \uff0c \u5178\u578b \u75c5\u7406 \u6539\u53d8 \u4e3a \u652f\u6c14\u7ba1 \u58c1 \u7ec4\u7ec7 \u7684 \u7834\u574f \u6240\u81f4 \u7684 \u7ba1\u8154 \u53d8\u5f62 \uff0c \u6269\u5927 \uff0c \u5e76 \u53ef \u51f9\u9677 \uff0c \u8154 \u5185 \u542b\u6709 \u591a\u91cf \u5206\u6ccc\u7269 \u3002',
#      u'tagged_tokens': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u652f\u6c14\u7ba1\u6269\u5f20</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'<disease>\u708e\u75c7</disease>',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'tags': [u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'disease',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA',
#       u'NA'],
#      u'title': u'\u8001\u5e74\u4eba\u652f\u6c14\u7ba1\u6269\u5f20',
#      u'tokens': [u'\u5e7c\u5e74',
#       u'\u652f\u6c14\u7ba1',
#       u'\u53d1\u80b2\u9636\u6bb5',
#       u'\u4ea7\u751f',
#       u'\u7684',
#       u'\u652f\u6c14\u7ba1\u6269\u5f20',
#       u'\u591a\u4e3a',
#       u'\u56ca',
#       u'\u72b6',
#       u'\uff0c',
#       u'\u6210\u5e74',
#       u'\u540e',
#       u'\u708e\u75c7',
#       u'\u7ee7\u53d1',
#       u'\u7684',
#       u'\u6269\u5f20',
#       u'\u5219',
#       u'\u591a',
#       u'\u4e3a',
#       u'\u67f1\u72b6',
#       u'\uff0c',
#       u'\u5178\u578b',
#       u'\u75c5\u7406',
#       u'\u6539\u53d8',
#       u'\u4e3a',
#       u'\u652f\u6c14\u7ba1',
#       u'\u58c1',
#       u'\u7ec4\u7ec7',
#       u'\u7684',
#       u'\u7834\u574f',
#       u'\u6240\u81f4',
#       u'\u7684',
#       u'\u7ba1\u8154',
#       u'\u53d8\u5f62',
#       u'\uff0c',
#       u'\u6269\u5927',
#       u'\uff0c',
#       u'\u5e76',
#       u'\u53ef',
#       u'\u51f9\u9677',
#       u'\uff0c',
#       u'\u8154',
#       u'\u5185',
#       u'\u542b\u6709',
#       u'\u591a\u91cf',
#       u'\u5206\u6ccc\u7269',
#       u'\u3002']},
#     u'_type': u'cause'}],
#   u'max_score': 51.66565,
#   u'total': 691},
#  u'timed_out': False,
#  u'took': 111}

# %%
body = {
        "query": {
            "bool": {
                "must": [
                    {"match": {"title": '外阴假上皮瘤样增生'}},
                    {"match": {"tagged_tokens": '人类乳头瘤病毒'}}
                ]
            }
        }
    }

es.count(index='baidu',body=body)['count']
# Out:
# 479

# %%
print u'\u5176\u4e2d \uff0c \u6700 \u591a\u89c1\u4e8e \u4f53\u6db2\u514d\u75ab\u7f3a\u9677 \u7684 \u75c5\u4eba \uff0c \u5982 X \u8fde\u9501 \u7684 \u4f4e\u4e19\u79cd\u7403\u86cb\u767d\u8840\u75c7 \u3001 \u666e\u901a \u53d8\u5f02\u578b\u514d\u75ab\u7f3a\u9677\u75c5 \uff0c IgG \u4e9a\u7c7b \u7f3a\u9677 \u4e5f \u4e3a \u652f\u6c14\u7ba1\u6269\u5f20 \u7684 \u75c5\u56e0 \u4e4b\u4e00 \u3002'
# Out:
# 其中 ， 最 多见于 体液免疫缺陷 的 病人 ， 如 X 连锁 的 低丙种球蛋白血症 、 普通 变异型免疫缺陷病 ， IgG 亚类 缺陷 也 为 支气管扩张 的 病因 之一 。
